# %% [markdown]
# # ReAct Baseline Colab Runner
#
# Use `Runtime -> Change runtime type -> GPU` before running this notebook.

# %%
# !nvidia-smi

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Set your repository URL below, then clone it.

# %%
REPO_URL = "https://github.com/YOUR_USERNAME/YOUR_REPO_NAME.git"
# !git clone {REPO_URL} /content/react-baseline
# %cd /content/react-baseline

# %%
# !pip install -r requirements.txt

# %%
# !curl -fsSL https://ollama.com/install.sh | sh

# %%
import subprocess, time

ollama_process = subprocess.Popen(["ollama", "serve"])
time.sleep(5)
# !ollama list

# %%
# !ollama pull qwen3:8b

# %%
# !python main.py ask "What does ReAct stand for?" --model-name qwen3:8b --max-iterations 3 --ollama-timeout 300

# %%
RESULT_DIR = "/content/drive/MyDrive/react_baseline_results"
# !mkdir -p {RESULT_DIR}
# !python main.py evaluate --dataset-path datasets/sample.json --output-path {RESULT_DIR}/evaluation_qwen3_8b.json --model-name qwen3:8b --max-iterations 3 --ollama-timeout 300
